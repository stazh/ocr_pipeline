# %% [markdown]
# # Lokales OCR-Setup (Tesseract + Calamari)
#
# Dieses Notebook hilft dir, die lokale Umgebung zu prüfen und vorzubereiten. Es installiert **nichts automatisch** systemweit, sondern zeigt dir klare Schritte.

# %% [markdown]
# ## Voraussetzungen (lokal)
#
# 1. Tesseract muss lokal installiert sein (inkl. Fraktur/Deutsch-Modelle, falls nötig).
# 2. Python-Pakete: `pytesseract`, `Pillow`, `numpy`, optional `matplotlib`.
# 3. Calamari OCR muss lokal installiert sein.
# 4. Ein Calamari-Frakturmodell muss lokal vorliegen (Pfad wird unten gesetzt).

# %%
from pathlib import Path
import shutil
import sys

# Funktioniert sowohl aus dem Repo-Root als auch aus ./notebooks.
CANDIDATE_ROOTS = [Path.cwd().resolve(), Path.cwd().resolve().parent]
PROJECT_ROOT = next((p for p in CANDIDATE_ROOTS if (p / 'Abl_1900_X__S__0287.tif').exists()), CANDIDATE_ROOTS[0])
TEST_IMAGE = PROJECT_ROOT / 'Abl_1900_X__S__0287.tif'
VENV311_BIN = PROJECT_ROOT / '.venv311' / 'bin'
CALAMARI_PREDICT_BIN = VENV311_BIN / 'calamari-predict'

print('Project root:', PROJECT_ROOT)
print('Test image exists:', TEST_IMAGE.exists(), TEST_IMAGE)

print('Python:', sys.version.split()[0])
print('tesseract in PATH:', shutil.which('tesseract'))
print('calamari-predict in PATH:', shutil.which('calamari-predict'))
print('calamari-predict in .venv311:', CALAMARI_PREDICT_BIN, CALAMARI_PREDICT_BIN.exists())
# Out:
# Project root: /Users/stazh/Documents/GithubRepos_stazh/ocr_2
# Test image exists: True /Users/stazh/Documents/GithubRepos_stazh/ocr_2/Abl_1900_X__S__0287.tif
# Python: 3.11.14
# tesseract in PATH: /opt/homebrew/bin/tesseract
# calamari-predict in PATH: /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/bin/calamari-predict
# calamari-predict in .venv311: /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/bin/calamari-predict True

# %% [markdown]
# ## Optionale Paketinstallation (im aktiven Environment)
#
# Wenn du in einer virtuellen Umgebung bist, kannst du diese Zelle einmalig ausführen.

# %%
# %pip install --upgrade pip
# %pip install jupyterlab pytesseract pillow numpy matplotlib calamari-ocr==2.3.1
# Out:
# Requirement already satisfied: pip in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (25.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jupyterlab in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (4.5.3)
# Requirement already satisfied: pytesseract in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (0.3.13)
# Requirement already satisfied: pillow in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (12.1.0)
# Requirement already satisfied: numpy in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: calamari-ocr==2.3.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: edit-distance in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from calamari-ocr==2.3.1) (1.0.7)
# Requirement already satisfied: h5py in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from calamari-ocr==2.3.1) (3.15.1)
# Requirement already satisfied: lxml in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from calamari-ocr==2.3.1) (6.0.2)
# Requirement already satisfied: python-bidi~=0.4.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from calamari-ocr==2.3.1) (0.4.2)
# Requirement already satisfied: tensorflow>=2.4.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from calamari-ocr==2.3.1) (2.15.1)
# Requirement already satisfied: ocrd-fork-tfaip>=1.2.7 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from calamari-ocr==2.3.1) (1.2.7)
# Requirement already satisfied: xlsxwriter in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from calamari-ocr==2.3.1) (3.2.9)
# Requirement already satisfied: six in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from python-bidi~=0.4.2->calamari-ocr==2.3.1) (1.17.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (7.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (26.0)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (80.10.2)
# Requirement already satisfied: tornado>=6.2.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (6.5.4)
# Requirement already satisfied: traitlets in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.12.1)
# Requirement already satisfied: certifi in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.32.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: typing_extensions>=4.5 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (9.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.2.1)
# Requirement already satisfied: decorator>=4.3.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-core->jupyterlab) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: ocrd-fork-adabelief-tf in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.2.1)
# Requirement already satisfied: dataclasses-json in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.5.5)
# Requirement already satisfied: GitPython in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (3.1.46)
# Requirement already satisfied: imageio in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (2.37.2)
# Requirement already satisfied: nptyping in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (2.5.0)
# Requirement already satisfied: opencv-python-headless in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (4.11.0.86)
# Requirement already satisfied: openpyxl in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (3.1.5)
# Requirement already satisfied: paiargparse==1.1.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (1.1.2)
# Requirement already satisfied: pandas in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (3.0.0)
# Requirement already satisfied: prettytable in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (3.17.0)
# Requirement already satisfied: python-Levenshtein in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.27.3)
# Requirement already satisfied: scikit-image in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.26.0)
# Requirement already satisfied: pooch==1.4.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (1.4.0)
# Requirement already satisfied: tensorflow-addons>=0.12.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.23.0)
# Requirement already satisfied: tqdm in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (4.67.1)
# Requirement already satisfied: typeguard in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (2.13.3)
# Requirement already satisfied: xlrd==1.2.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (1.2.0)
# Requirement already satisfied: editdistance in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from paiargparse==1.1.2->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.8.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from dataclasses-json->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (3.26.2)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from dataclasses-json->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from dataclasses-json->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.9.0)
# Requirement already satisfied: appdirs in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from pooch==1.4.0->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (1.4.4)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (4.25.8)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (3.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (1.76.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorflow>=2.4.0->calamari-ocr==2.3.1) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (2.48.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (1.2.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (3.10.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (3.1.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (46.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab) (2.6.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.6.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow>=2.4.0->calamari-ocr==2.3.1) (0.46.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (2.0.0)
# Requirement already satisfied: pycparser in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.4.0->calamari-ocr==2.3.1) (3.3.1)
# Requirement already satisfied: lark>=1.2.2 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from typing-inspect>=0.4.0->dataclasses-json->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (1.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.8.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from GitPython->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (5.0.2)
# Requirement already satisfied: arrow>=0.15.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: tzdata in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (2025.3)
# Requirement already satisfied: et-xmlfile in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from openpyxl->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (2.0.0)
# Requirement already satisfied: Levenshtein==0.27.3 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from python-Levenshtein->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.27.3)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from Levenshtein==0.27.3->python-Levenshtein->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (3.14.3)
# Requirement already satisfied: scipy>=1.11.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from scikit-image->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from scikit-image->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (3.6.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from scikit-image->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (2026.1.14)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/stazh/Documents/GithubRepos_stazh/ocr_2/.venv311/lib/python3.11/site-packages (from scikit-image->ocrd-fork-tfaip>=1.2.7->calamari-ocr==2.3.1) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Calamari-Frakturmodell konfigurieren
#
# Lege das Frakturmodell lokal ab und setze den Pfad hier. Du kannst auch mehrere Modellpfade angeben (Ensemble).

# %%
from pathlib import Path

# Default: das geklonte Ensemble-Modell fraktur_19th_century (0-4).
MODEL_DIR = Path('../models/calamari_models/fraktur_19th_century').resolve()
CALAMARI_MODEL_PATHS = [
    MODEL_DIR / '0.ckpt.json',
    MODEL_DIR / '1.ckpt.json',
    MODEL_DIR / '2.ckpt.json',
    MODEL_DIR / '3.ckpt.json',
    MODEL_DIR / '4.ckpt.json',
]

for p in CALAMARI_MODEL_PATHS:
    print(p, 'exists:', p.exists())
# Out:
# /Users/stazh/Documents/GithubRepos_stazh/ocr_2/models/calamari_models/fraktur_19th_century/0.ckpt.json exists: True
# /Users/stazh/Documents/GithubRepos_stazh/ocr_2/models/calamari_models/fraktur_19th_century/1.ckpt.json exists: True
# /Users/stazh/Documents/GithubRepos_stazh/ocr_2/models/calamari_models/fraktur_19th_century/2.ckpt.json exists: True
# /Users/stazh/Documents/GithubRepos_stazh/ocr_2/models/calamari_models/fraktur_19th_century/3.ckpt.json exists: True
# /Users/stazh/Documents/GithubRepos_stazh/ocr_2/models/calamari_models/fraktur_19th_century/4.ckpt.json exists: True

# %% [markdown]
# Wenn hier `exists: False` steht, ist der Pfad noch nicht korrekt gesetzt.
